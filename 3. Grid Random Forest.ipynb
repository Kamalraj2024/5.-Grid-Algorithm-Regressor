# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor=RandomForestRegressor(criterion="poisson",n_estimators = 100)
#regressor.fit(X_train,y_train)
#from sklearn.ensemble import RandomForestRegressor

#from sklearn.model_selection import GridSearchCV
#from sklearn.ensemble import RandomForestRegressor
#param_grid = {'criterion':['mse','mae'],'max_features': ['auto','sqrt','log2'], 'n_estimators':[10,100]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
              'max_features': ['sqrt','log2',None], 'n_estimators':[10,100]}


grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)

grid_predictions = grid.predict(X_test)
# print classification report
#from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.081169      0.004947         0.007630        0.001718
# 1        0.703381      0.014486         0.027113        0.000731
# 2        0.074018      0.002040         0.005984        0.000001
# 3        0.692012      0.008751         0.027128        0.001466
# 4        0.101482      0.001401         0.005586        0.000489
# 5        0.989636      0.011822         0.025352        0.001376
# 6        0.186928      0.040132         0.005389        0.000485
# 7        1.655170      0.047022         0.027527        0.002326
# 8        0.191915      0.024367         0.005782        0.000399
# 9        1.720393      0.024341         0.026529        0.001017
# 10       0.286756      0.016339         0.006499        0.001165
# 11       2.710213      0.016344         0.026530        0.002054
# 12       0.073201      0.001852         0.005964        0.000040
# 13       0.714042      0.014000         0.026131        0.000399
# 14       0.073118      0.000600         0.005586        0.000488
# 15       0.706977      0.008835         0.031746        0.003807
# 16       0.107445      0.006302         0.005785        0.000747
# 17       1.044891      0.022216         0.028304        0.003332
# 18       0.108743      0.053466         0.005585        0.000489
# 19       0.818850      0.024098         0.031740        0.001942
# 20       0.089269      0.004367         0.006388        0.000796
# 21       0.834062      0.024219         0.028924        0.000631
# 22       0.127476      0.004205         0.006637        0.000542
# 23       1.098975      0.152403         0.023162        0.004143
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4    squared_error               None                 10
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 10
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 10
# 9   absolute_error               log2                100
# 10  absolute_error               None                 10
# 11  absolute_error               None                100
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 10
# 15    friedman_mse               log2                100
# 16    friedman_mse               None                 10
# 17    friedman_mse               None                100
# 18         poisson               sqrt                 10
# 19         poisson               sqrt                100
# 20         poisson               log2                 10
# 21         poisson               log2                100
# 22         poisson               None                 10
# 23         poisson               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.774375
# 1   {'criterion': 'squared_error', 'max_features':...           0.809739
# 2   {'criterion': 'squared_error', 'max_features':...           0.781755
# 3   {'criterion': 'squared_error', 'max_features':...           0.805088
# 4   {'criterion': 'squared_error', 'max_features':...           0.793447
# 5   {'criterion': 'squared_error', 'max_features':...           0.801804
# 6   {'criterion': 'absolute_error', 'max_features'...           0.797791
# 7   {'criterion': 'absolute_error', 'max_features'...           0.798773
# 8   {'criterion': 'absolute_error', 'max_features'...           0.763626
# 9   {'criterion': 'absolute_error', 'max_features'...           0.796059
# 10  {'criterion': 'absolute_error', 'max_features'...           0.767275
# 11  {'criterion': 'absolute_error', 'max_features'...           0.787719
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.771882
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.809663
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.805895
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.806917
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.798849
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.806643
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.785264
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.802674
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.781057
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.813113
# 22  {'criterion': 'poisson', 'max_features': None,...           0.800804
# 23  {'criterion': 'poisson', 'max_features': None,...           0.809426
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.747506           0.826507           0.795556
# 1            0.763910           0.838659           0.833076
# 2            0.730769           0.813272           0.789383
# 3            0.759916           0.838439           0.832972
# 4            0.732088           0.824336           0.798357
# 5            0.761325           0.833914           0.803876
# 6            0.748984           0.829340           0.789961
# 7            0.768920           0.837898           0.831941
# 8            0.750097           0.823661           0.798298
# 9            0.770546           0.837639           0.819998
# 10           0.746830           0.826161           0.781532
# 11           0.769424           0.821057           0.810786
# 12           0.751808           0.830959           0.808733
# 13           0.773286           0.839627           0.827218
# 14           0.760043           0.806592           0.800499
# 15           0.770300           0.840922           0.836098
# 16           0.715225           0.815891           0.792953
# 17           0.748177           0.833156           0.801664
# 18           0.740523           0.828822           0.807096
# 19           0.763516           0.834666           0.829161
# 20           0.756573           0.794624           0.833587
# 21           0.774146           0.838844           0.830296
# 22           0.734046           0.827560           0.783881
# 23           0.752454           0.831631           0.808356
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.741675         0.777124        0.031368               20
# 1            0.761853         0.801448        0.032956                4
# 2            0.746070         0.772250        0.029909               24
# 3            0.755516         0.798386        0.035109                6
# 4            0.760178         0.781681        0.032118               15
# 5            0.762687         0.792721        0.027537                9
# 6            0.754767         0.784169        0.029536               13
# 7            0.766182         0.800743        0.030215                5
# 8            0.745619         0.776260        0.030052               21
# 9            0.761881         0.797225        0.028685                8
# 10           0.746718         0.773703        0.029342               22
# 11           0.760984         0.789994        0.023096               12
# 12           0.736694         0.780015        0.035096               18
# 13           0.761175         0.802194        0.030336                3
# 14           0.742078         0.783021        0.026790               14
# 15           0.760675         0.802982        0.032892                2
# 16           0.740336         0.772651        0.038237               23
# 17           0.761905         0.790309        0.031028               11
# 18           0.739098         0.780161        0.035712               17
# 19           0.759000         0.797803        0.031772                7
# 20           0.727429         0.778654        0.035749               19
# 21           0.766312         0.804542        0.029322                1
# 22           0.759092         0.781077        0.032413               16
# 23           0.758880         0.792149        0.030992               10

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[46577.3295371]
